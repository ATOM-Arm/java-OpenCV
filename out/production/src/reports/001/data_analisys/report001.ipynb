# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file
df = pd.read_csv("../csvs/performance206.csv")

# %%
df.head(15)
# Out:
#     frame  fingers  maxContourArea  centerX  centerY  convexDefects  avgAngle  \
# 0       0        1          7521.0   302.10   234.05              5      0.00
# 1       1        2         16140.0   279.71   286.44              6     41.16
# 2       2        3         26988.0   294.22   313.56              8     50.46
# 3       3        2         30147.0   296.25   319.56              9     57.23
# 4       4        2         31107.0   294.90   318.38              9     80.84
# 5       5        1         31495.5   295.79   319.86              6      0.00
# 6       6        2         31272.5   296.01   319.33              7     81.44
# 7       7        1         31709.5   295.62   318.93              7      0.00
# 8       8        1         31986.0   295.58   318.35              6      0.00
# 9       9        1         31878.5   295.43   319.42              9      0.00
# 10     10        2         31785.5   295.29   319.26              9     77.08
# ...
