# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file
df = pd.read_csv("../batch_results.csv")

# %%
df.head(15)
# Out:
#                                     file  fingers  maxContourArea  centerX  \
# IMG_20220430_180531.jpg 1 8741  50    88       45             101       12
# IMG_20220430_180538.jpg 1 8302  0     93       65             112       32
# IMG_20220430_180543.jpg 1 7702  50    96       56             101       16
# IMG_20220430_180553.jpg 1 8372  50    95       53             107       16
# IMG_20220430_180610.jpg 1 5777  0     99       65             107       89
# IMG_20220430_180617.jpg 1 5369  50   104       22              97       71
# IMG_20220430_180630.jpg 1 6548  50    93       51             102       59
# IMG_20220430_182941.jpg 1 5439  0     56       22              95       93
# IMG_20220501_151540.jpg 1 5048  0     62       17             112       19
# IMG_20220501_151543.jpg 1 5173  0     61       45             107       54
# IMG_20220501_151554.jpg 1 23104 50    96       60              84       46
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['frame'], df['time'], marker='o')
plt.title('Frame vs Time')
plt.xlabel('Frame')
plt.ylabel('Time (ms)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'frame'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure(figsize=(10, 6))
# ...
